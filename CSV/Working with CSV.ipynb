# %% [markdown]
# 1. Importing Pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.0 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.0 MB 3.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.0 MB 3.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.0 MB 3.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/11.0 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/11.0 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.0 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 3.7 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 3.7 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.0 MB 3.3 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %% [markdown]
# 2. Opening a local csv file

# %%
# df = pd.read_csv('file name')

# %% [markdown]
# 3. Opening a csv from server

# %%
# import requests
# from io import StringIO

# // Type your url here from that server file is available
# url = ""
# headers = {"User-Agent": "Mozilla/5.0","Accept": "text/csv"}

# req = requests.get(url,headers=headers)
# data = StringIO(req.text)

# pd.read_csv(data)

# %% [markdown]
# 4.  Sep parameter

# %%
# by default sep is ',' in case of reading csv that's why we use '\t' in sep for tsv files
# pd.read_csv('.tsv',sep='\t)

# %% [markdown]
# 5. Use cols parameter

# %%
# use this when we want only some columns not all 
# rather than later on , we can change it at the time of import as well
# pd.read_csv('.csv',,usecols=['name1','name2','name3'])
